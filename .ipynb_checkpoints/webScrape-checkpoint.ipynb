# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
import requests


# Define the URL and tickers

market_insiderUrl = 'https://markets.businessinsider.com/stocks/'
tickers = ['AMZN','TSLA','META','MSFT','GOOG','NVDA','AAPL']

news_tables = {}
for ticker in tickers:
    url = market_insiderUrl + ticker + '-stock/news'



    # Use BeautifulSoup to parse the loaded page
    print(url)
    response = requests.get(url)
    response.raise_for_status()  # This will raise an exception for HTTP errors

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    news_table = soup.findAll('a', class_='news-link')
    print(news_table)
    news_tables[ticker] = news_table

print(len(news_tables['MSFT']))
# Out:
# https://markets.businessinsider.com/stocks/AMZN-stock/news
# ...

# %%
print(news_tables['AAPL'])
# Out:
# [<a class="news-link" href="/news/stocks/apple-faces-difficult-china-demand-environment-results-could-be-better-than-feared-analyst-says-the-black-cloud-over-cupertino-1033234139">Apple Faces Difficult China Demand Environment, Results Could Be Better Than Feared, Analyst Says: 'The Black Cloud Over Cupertino'</a>, <a class="news-link" href="/news/stocks/analysts-offer-insights-on-technology-companies-amplitech-group-ampg-and-apple-aapl-1033234119">Analysts Offer Insights on Technology Companies: AmpliTech Group (AMPG) and Apple (AAPL)</a>, <a class="news-link" href="/news/stocks/the-bull-run-in-nvidia-stock-has-only-just-begun-heres-why-1033232895">The Bull Run In Nvidia Stock Has Only Just Begun. Here’s Why.</a>, <a class="news-link" href="/news/stocks/analysts-have-conflicting-sentiments-on-these-technology-companies-apple-aapl-and-versus-systems-vs-1033233475">Analysts Have Conflicting Sentiments on These Technology Companies: Apple (AAPL) and Versus Systems (VS)</a>, <a class="n
# ...

# %%
print(news_tables.items())
# Out:
# dict_items([('AMZN', [<a class="news-link" href="/news/stocks/7-mega-cap-stocks-poised-to-double-your-money-in-3-years-1033234226">7 Mega-Cap Stocks Poised to Double Your Money in 3 Years</a>, <a class="news-link" href="/news/stocks/amazon-mongodb-and-2-other-stocks-insiders-are-selling-1033233175">Amazon, MongoDB And 2 Other Stocks Insiders Are Selling</a>, <a class="news-link" href="/news/stocks/3-big-box-retail-stocks-that-could-double-your-money-by-2030-1033233925">3 Big-Box Retail Stocks That Could Double Your Money by 2030</a>, <a class="news-link" href="/news/stocks/looking-for-the-next-google-buy-these-7-tech-penny-stocks-1033233240">Looking for the Next Google? Buy These 7 Tech Penny Stocks</a>, <a class="news-link" href="/news/stocks/rivians-make-or-break-moment-can-the-new-tesla-deliver-on-2024-promises-1033232811">Rivian’s Make-or-Break Moment: Can the ‘New Tesla’ Deliver on 2024 Promises?</a>, <a class="news-link" href="/news/stocks/blue-chip-bonanza-7-stocks-to-surf-the
# ...

# %%
parsed_data = []




for ticker, news_table in news_tables.items():
    print(ticker)
    i = 0  # Initialize the counter outside of the inner loop
    for elem in news_table:
#         print(i)
#         i += 1  # Increment the counter here
#         if i > 50:
#             break  # Break the inner loop if more than 50 links have been processed

        try:
            articleInfo = ''
            if elem:
                
               
                link = elem.get('href')
                newUrl = 'https://markets.businessinsider.com' + link 

                # Use Selenium to navigate to the new URL
                response = requests.get(newUrl)
                response.raise_for_status()  # This will raise an exception for HTTP errors

                # Parse the HTML using BeautifulSoup
                soup = BeautifulSoup(response.text, 'html.parser')
                h1tag = soup.find('h1',class_='article-title')
                title = h1tag.text
                
                date = soup.find(class_news='post-quotetime warmGrey')
                date = date.text
                date = date.split

                content = soup.find('div', class_='col-xs-12 news-content no-padding')
                if content:
                # Extract all paragraphs, ignoring nested formatting tags by getting the .text
                    p_tags = content.find_all('p')
                    articleInfo = ' '.join(p.text.strip() for p in p_tags)
                    
                print(articleInfo)
                parsed_data.append([ticker, title, link, articleInfo])
                
        except Exception as e:
            print(f"An error occurred while fetching or parsing the article: {e}")
            continue  # Skip to the next loop iteration if an error occurs

df = pd.DataFrame(parsed_data, columns=['ticker', 'title', 'link', 'articleInfo'])
print(df.head())
# Out:
# AMZN
# ...

# %%
print(df['articleInfo'])
# Out:
# 0      InvestorPlace - Stock Market News, Stock Advic...
# 1      The Nasdaq 100 closed lower by around 8 points...
# 2      InvestorPlace - Stock Market News, Stock Advic...
# 3      InvestorPlace - Stock Market News, Stock Advic...
# 4      InvestorPlace - Stock Market News, Stock Advic...
#                              ...
# 309    InvestorPlace - Stock Market News, Stock Advic...
# 310    InvestorPlace - Stock Market News, Stock Advic...
# 311    (RTTNews) - Apple Inc. (AAPL) has announced it...
# 312    InvestorPlace - Stock Market News, Stock Advic...
# 313    InvestorPlace - Stock Market News, Stock Advic...
# Name: articleInfo, Length: 314, dtype: object

# %%
df.to_csv('stockNews.csv')
